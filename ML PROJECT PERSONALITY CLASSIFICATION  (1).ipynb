# %% [markdown]
# # 1. Load Libraries and Dataset

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("personality_dataset.csv")

# %% [markdown]
# # 2. Initial Data Inspection and Class Balance

# %%
print("Class distribution:")
print(df['Personality'].value_counts(normalize=True) * 100)
# Out:
# Class distribution:
# Personality
# Extrovert    51.413793
# Introvert    48.586207
# Name: proportion, dtype: float64

# %% [markdown]
# # 3. Handle Missing Values

# %%
num_cols = df.select_dtypes(include=['float64']).columns
cat_cols = ['Stage_fear', 'Drained_after_socializing']

num_imputer = SimpleImputer(strategy='mean')
df[num_cols] = num_imputer.fit_transform(df[num_cols])

cat_imputer = SimpleImputer(strategy='most_frequent')
df[cat_cols] = cat_imputer.fit_transform(df[cat_cols])

# %% [markdown]
# #  4. Encode Categorical Features

# %%
label_encoders = {}
for col in cat_cols + ['Personality']:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %% [markdown]
# #  5. Feature Scaling and Data Split

# %%
X = df.drop('Personality', axis=1)
y = df['Personality']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# # 6. Random Forest Classifier

# %%
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)
rf_score = rf_model.score(X_test, y_test)
print(f"Random Forest Accuracy: {rf_score:.4f}")

rf_preds = rf_model.predict(X_test)
cm_rf = confusion_matrix(y_test, rf_preds)

plt.figure(figsize=(6, 4))
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues',
            xticklabels=label_encoders['Personality'].classes_,
            yticklabels=label_encoders['Personality'].classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Random Forest')
plt.tight_layout()
plt.show()
# Out:
# Random Forest Accuracy: 0.9241

# %% [markdown]
# #  7. Logistic Regression Classifier

# %%
lr_model = LogisticRegression(random_state=42)
lr_model.fit(X_train, y_train)
lr_score = lr_model.score(X_test, y_test)
print(f"Logistic Regression Accuracy: {lr_score:.4f}")

lr_preds = lr_model.predict(X_test)

cm_lr = confusion_matrix(y_test, lr_preds)

plt.figure(figsize=(6, 4))
sns.heatmap(cm_lr, annot=True, fmt='d', cmap='Greens',
            xticklabels=label_encoders['Personality'].classes_,
            yticklabels=label_encoders['Personality'].classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Logistic Regression')
plt.tight_layout()
plt.show()
# Out:
# Logistic Regression Accuracy: 0.9190

# %% [markdown]
#  # 8. ANN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

y_train_oh = to_categorical(y_train)
y_test_oh = to_categorical(y_test)

model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(32, activation='relu'))
model.add(Dense(2, activation='softmax'))  

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(X_train, y_train_oh, epochs=50, batch_size=32, validation_data=(X_test, y_test_oh))

loss, accuracy = model.evaluate(X_test, y_test_oh)
print(f"ANN Accuracy (Keras): {accuracy:.4f}")
# Out:
# C:\Users\Admin\anaconda\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9159 - loss: 0.3273 - val_accuracy: 0.9293 - val_loss: 0.2710
# Epoch 2/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9358 - loss: 0.2528 - val_accuracy: 0.9293 - val_loss: 0.2603
# Epoch 3/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9358 - loss: 0.2404 - val_accuracy: 0.9293 - val_loss: 0.2536
# Epoch 4/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9358 - loss: 0.2329 - val_accuracy: 0.9293 - val_loss: 0.2509
# Epoch 5/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9358 - loss: 0.2281 - val_accuracy: 0.9293 - val_loss: 0.2459
# Epoch 6/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9358 - loss: 0.2227 - val_accuracy: 0.9293 - val_loss: 0.2460
# Epoch 7/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9358 - loss: 0.2199 - val_accuracy: 0.9293 - val_loss: 0.2444
# Epoch 8/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9358 - loss: 0.2178 - val_accuracy: 0.9293 - val_loss: 0.2426
# Epoch 9/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9358 - loss: 0.2163 - val_accuracy: 0.9293 - val_loss: 0.2409
# Epoch 10/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9358 - loss: 0.2161 - val_accuracy: 0.9293 - val_loss: 0.2421
# Epoch 11/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9358 - loss: 0.2169 - val_accuracy: 0.9293 - val_loss: 0.2475
# Epoch 12/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9358 - loss: 0.2145 - val_accuracy: 0.9293 - val_loss: 0.2385
# Epoch 13/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9353 - loss: 0.2105 - val_accuracy: 0.9293 - val_loss: 0.2412
# Epoch 14/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9358 - loss: 0.2125 - val_accuracy: 0.9293 - val_loss: 0.2378
# Epoch 15/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9358 - loss: 0.2110 - val_accuracy: 0.9293 - val_loss: 0.2385
# Epoch 16/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9358 - loss: 0.2129 - val_accuracy: 0.9293 - val_loss: 0.2384
# Epoch 17/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9358 - loss: 0.2090 - val_accuracy: 0.9293 - val_loss: 0.2385
# Epoch 18/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9358 - loss: 0.2081 - val_accuracy: 0.9293 - val_loss: 0.2463
# Epoch 19/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9358 - loss: 0.2097 - val_accuracy: 0.9293 - val_loss: 0.2369
# Epoch 20/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9358 - loss: 0.2090 - val_accuracy: 0.9293 - val_loss: 0.2390
# Epoch 21/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9358 - loss: 0.2078 - val_accuracy: 0.9293 - val_loss: 0.2378
# Epoch 22/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9353 - loss: 0.2071 - val_accuracy: 0.9293 - val_loss: 0.2382
# Epoch 23/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9358 - loss: 0.2055 - val_accuracy: 0.9293 - val_loss: 0.2454
# Epoch 24/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9358 - loss: 0.2077 - val_accuracy: 0.9293 - val_loss: 0.2361
# Epoch 25/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9362 - loss: 0.2076 - val_accuracy: 0.9293 - val_loss: 0.2372
# Epoch 26/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9353 - loss: 0.2053 - val_accuracy: 0.9293 - val_loss: 0.2445
# Epoch 27/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9353 - loss: 0.2057 - val_accuracy: 0.9293 - val_loss: 0.2402
# Epoch 28/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9358 - loss: 0.2050 - val_accuracy: 0.9276 - val_loss: 0.2368
# Epoch 29/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9358 - loss: 0.2047 - val_accuracy: 0.9276 - val_loss: 0.2360
# Epoch 30/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9358 - loss: 0.2056 - val_accuracy: 0.9276 - val_loss: 0.2347
# Epoch 31/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9349 - loss: 0.2037 - val_accuracy: 0.9293 - val_loss: 0.2364
# Epoch 32/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9353 - loss: 0.2033 - val_accuracy: 0.9293 - val_loss: 0.2380
# Epoch 33/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9358 - loss: 0.2030 - val_accuracy: 0.9293 - val_loss: 0.2383
# Epoch 34/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9353 - loss: 0.2054 - val_accuracy: 0.9293 - val_loss: 0.2363
# Epoch 35/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9358 - loss: 0.2042 - val_accuracy: 0.9276 - val_loss: 0.2344
# Epoch 36/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9358 - loss: 0.2022 - val_accuracy: 0.9276 - val_loss: 0.2406
# Epoch 37/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9353 - loss: 0.2041 - val_accuracy: 0.9293 - val_loss: 0.2360
# Epoch 38/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9353 - loss: 0.2024 - val_accuracy: 0.9276 - val_loss: 0.2347
# Epoch 39/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9362 - loss: 0.2019 - val_accuracy: 0.9276 - val_loss: 0.2371
# Epoch 40/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9358 - loss: 0.2020 - val_accuracy: 0.9293 - val_loss: 0.2415
# Epoch 41/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9358 - loss: 0.2008 - val_accuracy: 0.9293 - val_loss: 0.2354
# Epoch 42/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9349 - loss: 0.1998 - val_accuracy: 0.9293 - val_loss: 0.2343
# Epoch 43/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9353 - loss: 0.2010 - val_accuracy: 0.9293 - val_loss: 0.2335
# Epoch 44/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9349 - loss: 0.1998 - val_accuracy: 0.9293 - val_loss: 0.2325
# Epoch 45/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9353 - loss: 0.1991 - val_accuracy: 0.9293 - val_loss: 0.2348
# Epoch 46/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9349 - loss: 0.1976 - val_accuracy: 0.9293 - val_loss: 0.2384
# Epoch 47/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9358 - loss: 0.1999 - val_accuracy: 0.9293 - val_loss: 0.2341
# Epoch 48/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9353 - loss: 0.1989 - val_accuracy: 0.9293 - val_loss: 0.2291
# Epoch 49/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9349 - loss: 0.1986 - val_accuracy: 0.9293 - val_loss: 0.2368
# Epoch 50/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9358 - loss: 0.1983 - val_accuracy: 0.9293 - val_loss: 0.2313
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9293 - loss: 0.2313
# ANN Accuracy (Keras): 0.9293

# %%
import numpy as np
ann_probs = model.predict(X_test)

ann_preds_keras = np.argmax(ann_probs, axis=1)

cm_keras_ann = confusion_matrix(y_test, ann_preds_keras)

plt.figure(figsize=(6, 4))
sns.heatmap(cm_keras_ann, annot=True, fmt='d', cmap='Purples',
            xticklabels=label_encoders['Personality'].classes_,
            yticklabels=label_encoders['Personality'].classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - ANN (Keras)')
plt.tight_layout()
plt.show()
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
